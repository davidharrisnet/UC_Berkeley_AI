# %% [markdown]
# # Module 5

# %% [markdown]
# 1. Career Development Module
# 1. Career Development Module
# 1. Practical Application
#    1. GitHub
#    2. Data Driven Decisions
#       1. Amazon targeted coupons
# 1. Mentoring Module
#     1. Overview of Career field
#     1. Interact with ML/AI Professional
