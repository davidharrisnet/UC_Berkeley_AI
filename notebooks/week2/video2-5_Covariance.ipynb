# %% [markdown]
# ---
# # <center>Pandas correlations and introduction to [Seaborn](https://seaborn.pydata.org/)</center>
# ---

# %% [markdown]
# ## Import statement

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Load the data

# %%
gentoo = pd.read_csv('data/gentoo.csv')
gentoo = gentoo[['Bill length' ,'Bill depth' ,'Flipper Length (mm)' ,'Body Mass (g)']]
gentoo
# Out:
#      Bill length  Bill depth  Flipper Length (mm)  Body Mass (g)
# 0           46.1        13.2                  211           4500
# 1           50.0        16.3                  230           5700
# 2           48.7        14.1                  210           4450
# 3           50.0        15.2                  218           5700
# 4           47.6        14.5                  215           5400
# ..           ...         ...                  ...            ...
# 114         47.2        13.7                  214           4925
# 115         46.8        14.3                  215           4850
# 116         50.4        15.7                  222           5750
# 117         45.2        14.8                  212           5200
# 118         49.9        16.1                  213           5400
#
# [119 rows x 4 columns]

# %%
gentoo.describe()
# Out:
#        Bill length  Bill depth  Flipper Length (mm)  Body Mass (g)
# count   119.000000  119.000000           119.000000     119.000000
# mean     47.568067   14.996639           217.235294    5092.436975
# std       3.106116    0.985998             6.585431     501.476154
# min      40.900000   13.100000           203.000000    3950.000000
# 25%      45.350000   14.200000           212.000000    4700.000000
# 50%      47.400000   15.000000           216.000000    5050.000000
# 75%      49.600000   15.750000           221.500000    5500.000000
# max      59.600000   17.300000           231.000000    6300.000000

# %% [markdown]
# ## Covariance matrix
#
# ![sdv](samp_cov_eq.png)

# %%
gentoo.cov()
# Out:
#                      Bill length  Bill depth  Flipper Length (mm)  \
# Bill length             9.647955    2.003027            13.586391
# Bill depth              2.003027    0.972192             4.614357
# Flipper Length (mm)    13.586391    4.614357            43.367896
# Body Mass (g)        1038.527631  357.474363          2349.040379
#
#                      Body Mass (g)
# Bill length            1038.527631
# Bill depth              357.474363
# Flipper Length (mm)    2349.040379
# Body Mass (g)        251478.332859

# %% [markdown]
# ## Correlation matrix

# %%
gentoo.corr()
# Out:
#                      Bill length  Bill depth  Flipper Length (mm)  \
# Bill length             1.000000    0.654023             0.664205
# Bill depth              0.654023    1.000000             0.710642
# Flipper Length (mm)     0.664205    0.710642             1.000000
# Body Mass (g)           0.666730    0.722967             0.711305
#
#                      Body Mass (g)
# Bill length               0.666730
# Bill depth                0.722967
# Flipper Length (mm)       0.711305
# Body Mass (g)             1.000000

# %% [markdown]
# ## Correlations matrix plot

# %%
sns.pairplot(gentoo)
