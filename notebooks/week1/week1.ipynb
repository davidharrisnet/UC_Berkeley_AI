# %%
import pandas as pd
import numpy as np

# %%
arr = np.array([1, 3, 5, 5, 7, 7, 7, 9])

# %%
stat.mode(arr)
# Out:
# 7

# %%
stat.median(arr) # stat truncates the me
# Out:
# 6.0

# %%
stat.mean(arr) # stat truncates the mean -- the actual value is 5.5
# Out:
# 5

# %%
def stats(arr):
    return f"{arr}\nmean {stat.mean(arr)} \n\nmedian {stat.median(arr)}\nmode {stat.mode(arr)}"

# %%
print(stats(arr))
# Out:
# [1 3 5 5 7 7 7 9]
# mean 5
#
# median 6.0
# mode 7

# %%
sum(arr)/ len(arr)
# Out:
# 5.5

# %%
stat.mean(arr)
# Out:
# 5

# %%
arr = [10, 12, 23, 23, 16, 23, 21, 16]

# %%
df = pd.DataFrame(arr)

# %%
df.describe()
# Out:
#                0
# count   8.000000
# mean   18.000000
# std     5.237229
# min    10.000000
# 25%    15.000000
# 50%    18.500000
# 75%    23.000000
# max    23.000000

# %%
m = np.array(arr)

# %%
#arr = [-6,-4,-2,1,1,2,2,2,6,8]
#arr = [10, 19, 5, 34, 30, 11, 14, 10]
arr = [0, 4, 9, 6, 7, 4, 3]

# %%
def nump(arr):
    n = np.array(arr)
    return n.mean()

# %%
print(nump(arr))
# Out:
# 4.714285714285714
