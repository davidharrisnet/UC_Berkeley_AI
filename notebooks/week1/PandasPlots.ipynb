# %%
import pandas as pd
import numpy as np

# %%
data = {'A':[0.1, 0.2, 0.3], 'B':[10, 20, 30]}

# %%
table = pd.DataFrame(data)

# %%
table
# Out:
#      A   B
# 0  0.1  10
# 1  0.2  20
# 2  0.3  30

# %%
type(table['A'])
# Out:
# pandas.core.series.Series

# %%
a = table['A']

# %%
table['A'].sum()
# Out:
# 0.6000000000000001

# %%
table['C'] = table['A'].add(table['B'])

# %%
table
# Out:
#      A   B     C
# 0  0.1  10  10.1
# 1  0.2  20  20.2
# 2  0.3  30  30.3

# %%
 table['A'].multiply(table['B'])
# Out:
# 0    1.0
# 1    4.0
# 2    9.0
# dtype: float64

# %%
# be careful. sum is used to sum the series elements, not add two serieses together.
try:
  table['A'].sum(table['B'])
except Exception as e:
    print(e)
# Out:
# unhashable type: 'Series'

# %% [markdown]
# # plotting

# %%
from sklearn import datasets
X = datasets.load_iris(as_frame=True)
df = X.frame
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sklearn import datasets
#       2 X = datasets.load_iris(as_frame=True)
#       3 df = X.frame
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import sklearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import sklearn
#
# ModuleNotFoundError: No module named 'sklearn'
