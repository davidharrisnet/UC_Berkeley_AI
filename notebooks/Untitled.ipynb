# %%
import numpy as np

# %%
mass = [12, 20, 32]

# %%
volume = [ 36, 18, 10 ]

# %%
mvlist = [mass, volume]

# %%
type(mvlist)
# Out:
# list

# %%
print(mvlist)
# Out:
# [[12, 20, 32], [36, 18, 10]]

# %%
mvndarray = np.array(mvlist)

# %%
type(mvndarray)
# Out:
# numpy.ndarray

# %%
print(mvndarray)
# Out:
# [[12 20 32]
#  [36 18 10]]

# %%
mvndarray.shape
# Out:
# (2, 3)

# %%
mvndarray[0]
# Out:
# array([12, 20, 32])

# %%
mvndarray[1]
# Out:
# array([36, 18, 10])

# %%
mvndarray[1,2]
# Out:
# np.int64(10)

# %%
mvndarray[0:2, 1:2]
# Out:
# array([[20],
#        [18]])

# %%
mvndarray
# Out:
# array([[12, 20, 32],
#        [36, 18, 10]])

# %%
mvndarray[0,1:3]
# Out:
# array([20, 32])

# %%
mvndarray[1,1:3]
# Out:
# array([18, 10])

# %%
mvndarray[1:2,1:3]
# Out:
# array([[18, 10]])
